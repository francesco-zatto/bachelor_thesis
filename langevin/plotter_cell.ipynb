# %%
import matplotlib.pyplot as plt
import pandas as pd
from random import randint

# %%
df = pd.read_csv("data.csv", sep=";").iloc[:, :-1]

# %%
for i in range(0, len(df.columns), 2):
    plot = plt.scatter(df.iloc[:, i], df.iloc[:, i + 1], s=0.01) #every position
    #plt.scatter(df.iloc[0, i], df.iloc[0, i + 1], c="black", marker="*") #start
    #plt.scatter(df.iloc[-1, i], df.iloc[-1, i + 1], c="black", marker="*") #end
plt.savefig("images/plot_discrete_grid_5_100000.png")
