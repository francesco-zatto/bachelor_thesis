# %%
import matplotlib.pyplot as plt
import pandas as pd
from random import randint

# %%
df = pd.read_csv("data.csv", sep=";", header=None)

# %%
df.iloc[0, 0], df.iloc[0, 1]
# Out:
# (-7e-05, -0.000142)

# %%
plt.plot(df[0], df[1]);
plt.plot(df.iloc[0, 0], df.iloc[0, 1], c="red", marker="*")
plt.plot(df.iloc[-1, 0], df.iloc[-1, 1], c="red", marker="*")
visc = "10"
mass = "1000"
it = "1000"
plt.title("Viscosity= " + visc + ", mass= " + mass + ", iterations= " + it)
plt.savefig("images/plot" + str(randint(0, 10_000)) + ".png")
