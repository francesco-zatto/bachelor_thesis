# %%
import matplotlib.pyplot as plt
import pandas as pd
from random import randint

# %%
df = pd.read_csv("start.csv", sep=";", header=None).iloc[:, :-1]
df
# Out:
#             0       1
# 0        67.0  1156.0
# 1      1956.0    68.0
# 2       378.0  1307.0
# 3       405.0   326.0
# 4       803.0    45.0
# ...       ...     ...
# 69995  1898.0    71.0
# 69996  1344.0   568.0
# 69997  1287.0   708.0
# 69998  1995.0  1901.0
# 69999   173.0   277.0
#
# [70000 rows x 2 columns]

# %%
for i in range(0, len(df.columns), 2):
    plot = plt.scatter(df.iloc[:, i], df.iloc[:, i + 1], s=0.1) #every position
    #plt.scatter(df.iloc[0, i], df.iloc[0, i + 1], c="black", marker="*") #start
    #plt.scatter(df.iloc[-1, i], df.iloc[-1, i + 1], c="black", marker="*") #end
#plt.savefig("images/plot_discrete_grid_5_80000.png")
