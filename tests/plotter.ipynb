# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import pandas as pd

# %%
df = pd.read_csv("start.csv", sep=";")

# %%
colors = df["Type"].apply(lambda t: "darkorange" if t == 2 else "green" if t == 1 else "blue")
sizes = df["Type"].apply(lambda t: 0.2 if t == 2 else 1.5)
plt.scatter(df["X"], df["Y"], c=colors, s=sizes)
plt.savefig("images/plot_gen_7000.png")
